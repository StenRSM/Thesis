# %% [markdown]
# # Research question 3

# %%
import pandas as pd

# %%
data_pan15_train = pd.read_csv(r'C:\Users\Sten\Documents\EUR BIM\thesis\data\data\raw_data\PAN_15_training.csv')

# %%
authors = data_pan15_train[data_pan15_train['gender'] == 'M']
selected_authors = authors['author'].drop_duplicates().sample(n=5, random_state=7367).tolist()

# %%
authors = data_pan15_train[data_pan15_train['gender'] == 'F']
selected_authors = authors['author'].drop_duplicates().sample(n=5, random_state=9254).tolist()

# %%
authors = data_pan15_train[data_pan15_train['age'] == '18-24']
selected_authors = authors['author'].drop_duplicates().sample(n=5, random_state=1425).tolist()

# %%
authors = data_pan15_train[data_pan15_train['age'] == '25-34']
selected_authors = authors['author'].drop_duplicates().sample(n=5, random_state=6429).tolist()

# %%
authors = data_pan15_train[data_pan15_train['age'] == '35-49']
selected_authors = authors['author'].drop_duplicates().sample(n=5, random_state=9345).tolist()

# %%
authors = data_pan15_train[data_pan15_train['age'] == '50-XX']
selected_authors = authors['author'].drop_duplicates().sample(n=5, random_state=8434).tolist()

# %%
selected_tweets = pd.DataFrame()

# %%
for author in selected_authors:
    author_tweets = authors[authors['author'] == author]
    selected_author_tweets = author_tweets.sample(n=10, random_state=8522)
    selected_tweets = pd.concat([selected_tweets, selected_author_tweets])

# %%
all_tweets = '"' + '", "'.join(selected_tweets['text'].tolist()) + '"'
#all_tweets = ' '.join(selected_tweets['text'].tolist())

# %%
all_tweets
# Out:
# '"I posted a new photo to Facebook http://t.co/59860T3i\t\t", "I posted a new photo to Facebook http://t.co/LX6BuAJL\t\t", ""Essential Zen Habits of 2012"  http://t.co/1la7bWtZ good read\t\t", "The salmon struggle: A fish by any other color is just not natural - http://t.co/rLBFx7mC http://www.http://t.co/ZZsr4E7R\t\t", "I posted a new photo to Facebook http://t.co/4sEhrIC855\t\t", "Entrepreneurs Set the Course for our Nation http://t.co/njo8paKE\t\t", "I liked a @username video from @username http://t.co/lQIKLU4W LEARN TO SAVE $$$ ON YOUR TAXES!!\t\t", "I uploaded a new video to my Youtube channel. http://t.co/4LFpXf6BTI\t\t", "Motives in the News. Checkout http://t.co/atuCvAyR @username @username http://t.co/tu1Yvncb\t\t", "I posted a new photo to Facebook http://t.co/nkNUDWF5\t\t", "http://t.co/kBf25vrOeJ . Cool!!..\t\t", "@username wow...eso es amor. Gracias...besooo\t\t", "@username You can\'t destroy middle west culture and kill innocent people. Yes..you can!!\t\t", "@username thanks...????\t\t", "@username ????????????bon apetite\t\t", "@username from colombia, great show #Cosmos. Ted should present a Darwin chapter by the way.\t\t", "@username and then exhale, pleaseeee...????\t\t", "AWWWORRRRGGGHH!! Chirp. #Chewie #AngryBirdsStarWars http://t.co/ugrEYpwknV\t\t", "WWEEEOOOWWW! Chirp. #R2D2 #AngryBirdsStarWars http://t.co/92RK8Zi3Jr\t\t", "@username kisses....thanks for watching the show. And happy bday to you...\t\t", "“@username: "Generosity is giving more than you can, and pride is taking less than you need." - Kahlil Gibran”\t\t", "“@username: Words are the most powerful tool of leadership.”\t\t", "@username Thanks Iya, where can I find that book? I just don\'t get it.\t\t", "@username: “Executives and HR managers know coaching is the most potent tool for inducing lasting personal change.” (Ivy Business Journal)”\t\t", "@username muy lindo Fer! Kids always give us lessons :)\t\t", "“@username: #Leos choose their company based on morals and personality. Keep it classy or keep it moving.”\t\t", "Beauty isn\'t in the mirror, It\'s in the light of your heart! #quote\t\t", "“@username: High #EQ leaders create a safe, inspiring environment for every person, every day. ~Chris Edmonds”\t\t", "@username yeahhhh!!! Gracias\t\t", "@username woooow a buscar hacer esos viajes!\t\t", "“@username:  A #London night out is the most exp in the world http://t.co/zibMbJuD” @username @username @username”// pus q incluye??\t\t", "“@username: Echa un vistazo a los hombres más calientes de Hollywood http://t.co/TCnAY13x - // nahhh falta matthew mcconaughey\t\t", ""@username: 42 beers & 2 whisky bottles & still stand up,  isn\'t @username @username @username"/// y hoy ??  Como estan\t\t", ""@username: @username como te lo dije!! #superpeso" when you are right, you are right :)\t\t", "I got 3,354 points while escaping from demon monkeys in Temple Run. Beat that! http://t.co/1F1OHsh3\t\t", "Maybe in another life... ?\t\t", "Here\'s a list of the top travel destinations for next year ://t.co/0ZQrQZ3U” @username @username opciones para vac (yo ya conozco?)\t\t", "@username sorry. Sometimes you are not  right. Mex was the best in that match\t\t", "@username esta es para ti #10cancionesparasanvalentinhttp://m.youtube.com/?rdm=4ozmbjqgd&reload=3#/watch?v=aUuKm0-dwsQ\t\t", "We tryed, but we coudnt!! @username\t\t", "Lazy Saturday night....first in a long time. Totally OK with that. :) — feeling sleepy\t\t", "Fear is the Root of Your Problems http://t.co/Pk36KrIKjj\t\t", "#random Today almost makes me miss working election days with my former Patch colleagues. Something about the... http://t.co/Kwr6N4da4j\t\t", "This Moment http://t.co/d83wSFHY2h\t\t", "What the Exercise Habit Did For Me http://t.co/B46K34l6ii\t\t", "Abundance: Free Opportunity to Create a Better Life, Have More Money http://t.co/89X0frzMGo\t\t", "And then you wait.\t\t", "White House hosts student film festival http://t.co/QyFEHRcrz4 via @username\t\t", "Fountain of Youth: Do HGH P ...

# %%
selected_tweets
# Out:
#        Unnamed: 0                                author  \
# 9165         9165  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9154         9154  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9133         9133  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9129         9129  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9170         9170  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9107         9107  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9157         9157  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9186         9186  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9116         9116  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 9140         9140  a49c605b-81b9-463c-8e49-a9a6e06f3856
# 5500         5500  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5493         5493  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5492         5492  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5495         5495  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5514         5514  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5506         5506  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5517         5517  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5487         5487  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5483         5483  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5482         5482  69269faf-28b6-47aa-9fa0-cb4b30c684a6
# 5337         5337  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5343         5343  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5355         5355  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5317         5317  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5357         5357  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5322         5322  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5307         5307  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5364         5364  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5347         5347  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 5339         5339  68b27ee9-bf56-45db-be9a-2e0970d2b6b8
# 12790       12790  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12780       12780  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12805       12805  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12813       12813  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12791       12791  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12787       12787  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12775       12775  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12793       12793  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12786       12786  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 12808       12808  e5b59ccc-2053-4e8b-ba11-dfeeff92dd5d
# 13643       13643  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13632       13632  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13611       13611  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13607       13607  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13648       13648  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13585       13585  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13635       13635  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13664       13664  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13594       13594  f28ad171-3a6b-4f88-a3c9-feebe7b86747
# 13618       13618  f28ad171-3a6b-4f88-a3c9-feebe7b86747
#
#                                                     text gender    age
# 9165   I posted a new photo to Facebook http://t.co/5...      M  35-49
# 9154   I posted a new photo to Facebook http://t.co/L...      M  35-49
# 9133   "Essential Zen Habits of 2012"  http://t.co/1l...      M  35-49
# 9129   The salmon struggle: A fish by any other color...      M  35-49
# 9170   I posted a new photo to Facebook http://t.co/4...      M  35-49
# 9107   Entrepreneurs Set the Course for our Nation ht...      M  35-49
# 9157   I liked a @username video from @username http:...      M  35-49
# 9186   I uploaded a new video to my Youtube channel. ...      M  35-49
# 9116   Motives in the News. Checkout http://t.co/atuC...      M  35-49
# 9140   I posted a new photo to Facebook http://t.co/n...      M  35-49
# 5500               http://t.co/kBf25vrOeJ . Cool!!..\t\t      M  35-49
# 5493   @username wow...eso es amor. Gracias...besooo\t\t      M  35-49
# 5492   @username You can't destroy middle west cultur...      M  35-49
# 5495                         @username thanks...????\t\t      M  35-49
# 5514               @username ????????????bon apetite\t\t      M  35-49
# 5506   @username from colombia, great show #Cosmos. T...      M  35-49
# 5517     @username and then exhale, pleaseeee...????\t\t      M  35-49
# 5487   AWWWORRRRGGGHH!! Chirp. #Chewie #AngryBirdsSta...      M  35-49
# 5483   WWEEEOOOWWW! Chirp. #R2D2 #AngryBirdsStarWars ...      M  35-49
# 5482   @username kisses....thanks for watching the sh...      M  35-49
# 5337   “@username: "Generosity is giving more than yo...      F  35-49
# 5343   “@username: Words are the most powerful tool o...      F  35-49
# 5355   @username Thanks Iya, where can I find that bo...      F  35-49
# 5317   @username: “Executives and HR managers know co...      F  35-49
# 5357   @username muy lindo Fer! Kids always give us l...      F  35-49
# 5322   “@username: #Leos choose their company based o...      F  35-49
# 5307   Beauty isn't in the mirror, It's in the light ...      F  35-49
# 5364   “@username: High #EQ leaders create a safe, in...      F  35-49
# 5347                    @username yeahhhh!!! Gracias\t\t      F  35-49
# 5339    @username woooow a buscar hacer esos viajes!\t\t      F  35-49
# 12790  “@username:  A #London night out is the most e...      F  35-49
# 12780  “@username: Echa un vistazo a los hombres más ...      F  35-49
# 12805  "@username: 42 beers & 2 whisky bottles & stil...      F  35-49
# 12813  "@username: @username como te lo dije!! #super...      F  35-49
# 12791  I got 3,354 points while escaping from demon m...      F  35-49
# 12787                     Maybe in another life... ?\t\t      F  35-49
# 12775  Here's a list of the top travel destinations f...      F  35-49
# 12793  @username sorry. Sometimes you are not  right....      F  35-49
# 12786  @username esta es para ti #10cancionesparasanv...      F  35-49
# 12808            We tryed, but we coudnt!! @username\t\t      F  35-49
# 13643  Lazy Saturday night....first in a long time. T...      F  35-49
# 13632  Fear is the Root of Your Problems http://t.co/...      F  35-49
# 13611  #random Today almost makes me miss working ele...      F  35-49
# 13607             This Moment http://t.co/d83wSFHY2h\t\t      F  35-49
# 13648  What the Exercise Habit Did For Me http://t.co...      F  35-49
# 13585  Abundance: Free Opportunity to Create a Better...      F  35-49
# 13635                             And then you wait.\t\t      F  35-49
# 13664  White House hosts student film festival http:/...      F  35-49
# 13594  Fountain of Youth: Do HGH Pills Work? http://t...      F  35-49
# 13618  Is Honey Boo Boo the Definition of an American...      F  35-49

# %%
all_tweets_llama = '"' + '", "'.join(selected_tweets['text'].sample(n=25, random_state=8365).tolist()) + '"'

# %%
all_tweets_llama
# Out:
# '"I liked a @username video from @username http://t.co/lQIKLU4W LEARN TO SAVE $$$ ON YOUR TAXES!!\t\t", "Abundance: Free Opportunity to Create a Better Life, Have More Money http://t.co/89X0frzMGo\t\t", ""Essential Zen Habits of 2012"  http://t.co/1la7bWtZ good read\t\t", "Lazy Saturday night....first in a long time. Totally OK with that. :) — feeling sleepy\t\t", "@username and then exhale, pleaseeee...????\t\t", "I got 3,354 points while escaping from demon monkeys in Temple Run. Beat that! http://t.co/1F1OHsh3\t\t", "I posted a new photo to Facebook http://t.co/nkNUDWF5\t\t", "Motives in the News. Checkout http://t.co/atuCvAyR @username @username http://t.co/tu1Yvncb\t\t", "Beauty isn\'t in the mirror, It\'s in the light of your heart! #quote\t\t", "http://t.co/kBf25vrOeJ . Cool!!..\t\t", "@username Thanks Iya, where can I find that book? I just don\'t get it.\t\t", "“@username: High #EQ leaders create a safe, inspiring environment for every person, every day. ~Chris Edmonds”\t\t", "@username yeahhhh!!! Gracias\t\t", "“@username: Echa un vistazo a los hombres más calientes de Hollywood http://t.co/TCnAY13x - // nahhh falta matthew mcconaughey\t\t", "Is Honey Boo Boo the Definition of an American Family? http://t.co/chfkAZXcFm\t\t", "This Moment http://t.co/d83wSFHY2h\t\t", "WWEEEOOOWWW! Chirp. #R2D2 #AngryBirdsStarWars http://t.co/92RK8Zi3Jr\t\t", "@username woooow a buscar hacer esos viajes!\t\t", "What the Exercise Habit Did For Me http://t.co/B46K34l6ii\t\t", "Here\'s a list of the top travel destinations for next year ://t.co/0ZQrQZ3U” @username @username opciones para vac (yo ya conozco?)\t\t", "@username ????????????bon apetite\t\t", "“@username: Words are the most powerful tool of leadership.”\t\t", "Fountain of Youth: Do HGH Pills Work? http://t.co/nMVI8zBTfA on @username\t\t", "@username from colombia, great show #Cosmos. Ted should present a Darwin chapter by the way.\t\t", "“@username: "Generosity is giving more than you can, and pride is taking less than you need." - Kahlil Gibran”\t\t"'

# %%
selected_tweets['text'].sample(n=25, random_state=8365)
# Out:
# 9689     #pecaja And now for something completely diffe...
# 5013     "@username: Remember , u dumped me like trash ...
# 9665        @username @username Reichards Brothers ...\t\t
# 5071     RT @username: The three C's http://t.co/9SkS3g...
# 13635                               And then you wait.\t\t
# 5461     India's GDP likely to grow by 5.6 per cent thi...
# 9672                                       bibliotheek\t\t
# 9648     Pay us for library ebook loans, say authors ht...
# 5307     Beauty isn't in the mirror, It's in the light ...
# 13643    Lazy Saturday night....first in a long time. T...
# 5355     @username Thanks Iya, where can I find that bo...
# 5364     “@username: High #EQ leaders create a safe, in...
# 5347                      @username yeahhhh!!! Gracias\t\t
# 5445     China's Xiaomi shifts some smartphone user dat...
# 5046     "@username: If you gone cheat.. Bitch stay sin...
# 5035     "@username: "Don't ever give up a dream." - Em...
# 13594    Fountain of Youth: Do HGH Pills Work? http://t...
# 5339      @username woooow a buscar hacer esos viajes!\t\t
# 5076             Take me as I am, or watch me as I go.\t\t
# 5448     India's first fish hospital to come up in Kolk...
# 13648    What the Exercise Habit Did For Me http://t.co...
# 5343     “@username: Words are the most powerful tool o...
# 5022                 #NP Beyonce Ft. Jay-Z - Upgrade U\t\t
# 13585    Abundance: Free Opportunity to Create a Better...
# 5337     “@username: "Generosity is giving more than yo...
# Name: text, dtype: object
